# %% [markdown]
# # HPQRC Tutorial
#
# Introduction to Hybrid Photonic-Quantum Reservoir Computing for EV charging demand forecasting.

# %% [markdown]
# This notebook provides an introduction to the HPQRC model and its components.

# %%
import numpy as np
import torch

from src.models.hpqrc import HPQRC, HPQRCConfig
from src.data.synthetic import generate_synthetic_ev_demand
from src.data.preprocessing import normalize, create_sequences
from src.evaluation.metrics import compute_all_metrics

# %% [markdown]
# TODO: implement
