# %% [markdown]
# # Photonic Delay-Loop Emulation
#
# Understanding the photonic delay-loop emulator component.

# %% [markdown]
# This notebook explores the PDEL layer that emulates multiple temporal scales.

# %%
import torch

from src.photonic.delay_loop import PhotonicDelayBank, PhotonicDelayLoopEmulator
from src.photonic.kernels import random_kernels, chirp_kernels, gabor_kernels

# %% [markdown]
# TODO: implement
