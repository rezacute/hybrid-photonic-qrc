# %% [markdown]
# # Quantum Reservoir Computing
#
# Implementing quantum reservoirs with Qiskit 2.x.

# %% [markdown]
# This notebook covers the quantum reservoir component using Qiskit 2.x APIs.

# %%
import numpy as np

from src.quantum.reservoir import QuantumReservoir
from src.quantum.encoding import AngleEncoder, AmplitudeEncoder
from src.quantum.observables import PauliReadout

# %% [markdown]
# TODO: implement
