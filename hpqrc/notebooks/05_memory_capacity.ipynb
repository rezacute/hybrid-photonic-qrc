# %% [markdown]
# # Memory Capacity Analysis
#
# Benchmarking memory and information processing capacity.

# %% [markdown]
# This notebook analyzes the memory properties of different reservoir architectures.

# %%
import numpy as np

from src.data.synthetic import generate_synthetic_ev_demand
from src.evaluation.memory_capacity import (
    short_term_memory_capacity,
    information_processing_capacity,
)

# %% [markdown]
# TODO: implement
